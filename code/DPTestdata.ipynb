# %%
'''
CS 418: Final Project
Title - US Census Demographic Data - DATA PROCESSING -Applying changes on test data
Authors: Anusha Sagi, Fatima Kahack, Lydia Tse
Description: The following is code to analyze the US Census Data and preprocess it.
'''

# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load US Census Demographic Test Data
census_test_data = pd.read_csv('census_test_data.csv')
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop    Men  Women  Hispanic  \
# 0      1005  Alabama   Barbour County     26201  13976  12225       4.2
# 1      1025  Alabama    Clarke County     24625  11649  12976       0.2
# 2      1037  Alabama     Coosa County     10955   5474   5481       0.1
# 3      1047  Alabama    Dallas County     40755  18809  21946       1.0
# 4      1053  Alabama  Escambia County     37621  19326  18295       2.2
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 1   53.0   45.7     0.1  ...   0.7          2.7         0.9         23.9
# 2   65.3   33.2     0.1  ...   1.7          0.6         4.2         29.8
# 3   27.7   70.2     0.0  ...   1.7          1.4         1.2         22.1
# 4   60.2   32.2     3.6  ...   0.3          0.5         0.8         22.6
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0      8878         74.1        19.1           6.5         0.3          12.4
# 1      7933         83.1        11.8           5.1         0.0          15.2
# 2      3897         78.8        15.9           5.4         0.0          11.3
# 3     14461         78.8        15.2           5.6         0.4          13.7
# 4     12134         75.6        19.7           4.6         0.1          13.7
#
# [5 rows x 37 columns]

# %%
#Drop IncomeERR, IncomePerCapErr
census_test_data = census_test_data.drop(['IncomeErr', 'IncomePerCapErr'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop    Men  Women  Hispanic  \
# 0      1005  Alabama   Barbour County     26201  13976  12225       4.2
# 1      1025  Alabama    Clarke County     24625  11649  12976       0.2
# 2      1037  Alabama     Coosa County     10955   5474   5481       0.1
# 3      1047  Alabama    Dallas County     40755  18809  21946       1.0
# 4      1053  Alabama  Escambia County     37621  19326  18295       2.2
#
#    White  Black  Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  \
# 0   45.7   47.8     0.2  ...   2.2          1.7         1.3         23.4
# 1   53.0   45.7     0.1  ...   0.7          2.7         0.9         23.9
# 2   65.3   33.2     0.1  ...   1.7          0.6         4.2         29.8
# 3   27.7   70.2     0.0  ...   1.7          1.4         1.2         22.1
# 4   60.2   32.2     3.6  ...   0.3          0.5         0.8         22.6
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# 0      8878         74.1        19.1           6.5         0.3          12.4
# 1      7933         83.1        11.8           5.1         0.0          15.2
# 2      3897         78.8        15.9           5.4         0.0          11.3
# 3     14461         78.8        15.2           5.6         0.4          13.7
# 4     12134         75.6        19.7           4.6         0.1          13.7
#
# [5 rows x 35 columns]

# %%
#Percent Women - Test data
census_test_data['TotalPop'] = census_test_data['TotalPop'].astype(float)
census_test_data['Women'] = census_test_data['Women'].astype(float)
census_test_data['Percent_Women'] = (census_test_data['Women'] / census_test_data['TotalPop']) *100
census_test_data = census_test_data.drop(['Men', 'Women'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Hispanic  White  Black  \
# 0      1005  Alabama   Barbour County   26201.0       4.2   45.7   47.8
# 1      1025  Alabama    Clarke County   24625.0       0.2   53.0   45.7
# 2      1037  Alabama     Coosa County   10955.0       0.1   65.3   33.2
# 3      1047  Alabama    Dallas County   40755.0       1.0   27.7   70.2
# 4      1053  Alabama  Escambia County   37621.0       2.2   60.2   32.2
#
#    Native  Asian  Pacific  ...  OtherTransp  WorkAtHome  MeanCommute  \
# 0     0.2    0.6      0.0  ...          1.7         1.3         23.4
# 1     0.1    0.5      0.1  ...          2.7         0.9         23.9
# 2     0.1    0.0      0.0  ...          0.6         4.2         29.8
# 3     0.0    0.4      0.0  ...          1.4         1.2         22.1
# 4     3.6    0.4      0.1  ...          0.5         0.8         22.6
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0      8878         74.1        19.1           6.5         0.3          12.4
# 1      7933         83.1        11.8           5.1         0.0          15.2
# 2      3897         78.8        15.9           5.4         0.0          11.3
# 3     14461         78.8        15.2           5.6         0.4          13.7
# 4     12134         75.6        19.7           4.6         0.1          13.7
#
#    Percent_Women
# 0      46.658524
# 1      52.694416
# 2      50.031949
# 3      53.848608
# 4      48.629755
#
# [5 rows x 34 columns]

# %%
#drop % Pacific - lot of zeros(Other related columns have necessary data)
census_test_data = census_test_data.drop(['Pacific'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Hispanic  White  Black  \
# 0      1005  Alabama   Barbour County   26201.0       4.2   45.7   47.8
# 1      1025  Alabama    Clarke County   24625.0       0.2   53.0   45.7
# 2      1037  Alabama     Coosa County   10955.0       0.1   65.3   33.2
# 3      1047  Alabama    Dallas County   40755.0       1.0   27.7   70.2
# 4      1053  Alabama  Escambia County   37621.0       2.2   60.2   32.2
#
#    Native  Asian  VotingAgeCitizen  ...  OtherTransp  WorkAtHome  MeanCommute  \
# 0     0.2    0.6             20269  ...          1.7         1.3         23.4
# 1     0.1    0.5             19087  ...          2.7         0.9         23.9
# 2     0.1    0.0              8989  ...          0.6         4.2         29.8
# 3     0.0    0.4             30303  ...          1.4         1.2         22.1
# 4     3.6    0.4             29129  ...          0.5         0.8         22.6
#
#    Employed  PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment  \
# 0      8878         74.1        19.1           6.5         0.3          12.4
# 1      7933         83.1        11.8           5.1         0.0          15.2
# 2      3897         78.8        15.9           5.4         0.0          11.3
# 3     14461         78.8        15.2           5.6         0.4          13.7
# 4     12134         75.6        19.7           4.6         0.1          13.7
#
#    Percent_Women
# 0      46.658524
# 1      52.694416
# 2      50.031949
# 3      53.848608
# 4      48.629755
#
# [5 rows x 33 columns]

# %%
#drop Transit & FamilyWork - lot of zeros(Other related columns have necessary data)
census_test_data = census_test_data.drop(['Transit', 'FamilyWork'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Hispanic  White  Black  \
# 0      1005  Alabama   Barbour County   26201.0       4.2   45.7   47.8
# 1      1025  Alabama    Clarke County   24625.0       0.2   53.0   45.7
# 2      1037  Alabama     Coosa County   10955.0       0.1   65.3   33.2
# 3      1047  Alabama    Dallas County   40755.0       1.0   27.7   70.2
# 4      1053  Alabama  Escambia County   37621.0       2.2   60.2   32.2
#
#    Native  Asian  VotingAgeCitizen  ...  Walk  OtherTransp  WorkAtHome  \
# 0     0.2    0.6             20269  ...   2.2          1.7         1.3
# 1     0.1    0.5             19087  ...   0.7          2.7         0.9
# 2     0.1    0.0              8989  ...   1.7          0.6         4.2
# 3     0.0    0.4             30303  ...   1.7          1.4         1.2
# 4     3.6    0.4             29129  ...   0.3          0.5         0.8
#
#    MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  Unemployment  \
# 0         23.4      8878         74.1        19.1           6.5          12.4
# 1         23.9      7933         83.1        11.8           5.1          15.2
# 2         29.8      3897         78.8        15.9           5.4          11.3
# 3         22.1     14461         78.8        15.2           5.6          13.7
# 4         22.6     12134         75.6        19.7           4.6          13.7
#
#    Percent_Women
# 0      46.658524
# 1      52.694416
# 2      50.031949
# 3      53.848608
# 4      48.629755
#
# [5 rows x 31 columns]

# %%
#drop Employed column - redundant (We have unemployed %)
census_test_data = census_test_data.drop(['Employed'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Hispanic  White  Black  \
# 0      1005  Alabama   Barbour County   26201.0       4.2   45.7   47.8
# 1      1025  Alabama    Clarke County   24625.0       0.2   53.0   45.7
# 2      1037  Alabama     Coosa County   10955.0       0.1   65.3   33.2
# 3      1047  Alabama    Dallas County   40755.0       1.0   27.7   70.2
# 4      1053  Alabama  Escambia County   37621.0       2.2   60.2   32.2
#
#    Native  Asian  VotingAgeCitizen  ...  Carpool  Walk  OtherTransp  \
# 0     0.2    0.6             20269  ...     11.1   2.2          1.7
# 1     0.1    0.5             19087  ...     11.9   0.7          2.7
# 2     0.1    0.0              8989  ...      9.7   1.7          0.6
# 3     0.0    0.4             30303  ...      8.9   1.7          1.4
# 4     3.6    0.4             29129  ...      7.0   0.3          0.5
#
#    WorkAtHome  MeanCommute  PrivateWork  PublicWork  SelfEmployed  \
# 0         1.3         23.4         74.1        19.1           6.5
# 1         0.9         23.9         83.1        11.8           5.1
# 2         4.2         29.8         78.8        15.9           5.4
# 3         1.2         22.1         78.8        15.2           5.6
# 4         0.8         22.6         75.6        19.7           4.6
#
#    Unemployment  Percent_Women
# 0          12.4      46.658524
# 1          15.2      52.694416
# 2          11.3      50.031949
# 3          13.7      53.848608
# 4          13.7      48.629755
#
# [5 rows x 30 columns]

# %%
#Arranging columns
census_test_data = census_test_data[['CountyId', 'State', 'County', 'TotalPop', 'Percent_Women', 'Hispanic', 'White', 'Black', 'Native', 'Asian', 'VotingAgeCitizen', 'Income', 'IncomePerCap', 'Professional', 'Service', 'Office', 'Construction', 'Production', 'Drive', 'Carpool', 'Walk', 'OtherTransp', 'WorkAtHome', 'MeanCommute', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'Unemployment']]
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Percent_Women  Hispanic  \
# 0      1005  Alabama   Barbour County   26201.0      46.658524       4.2
# 1      1025  Alabama    Clarke County   24625.0      52.694416       0.2
# 2      1037  Alabama     Coosa County   10955.0      50.031949       0.1
# 3      1047  Alabama    Dallas County   40755.0      53.848608       1.0
# 4      1053  Alabama  Escambia County   37621.0      48.629755       2.2
#
#    White  Black  Native  Asian  ...  Drive  Carpool  Walk  OtherTransp  \
# 0   45.7   47.8     0.2    0.6  ...   83.4     11.1   2.2          1.7
# 1   53.0   45.7     0.1    0.5  ...   83.7     11.9   0.7          2.7
# 2   65.3   33.2     0.1    0.0  ...   83.2      9.7   1.7          0.6
# 3   27.7   70.2     0.0    0.4  ...   86.6      8.9   1.7          1.4
# 4   60.2   32.2     3.6    0.4  ...   91.3      7.0   0.3          0.5
#
#    WorkAtHome  MeanCommute  PrivateWork  PublicWork  SelfEmployed  \
# 0         1.3         23.4         74.1        19.1           6.5
# 1         0.9         23.9         83.1        11.8           5.1
# 2         4.2         29.8         78.8        15.9           5.4
# 3         1.2         22.1         78.8        15.2           5.6
# 4         0.8         22.6         75.6        19.7           4.6
#
#    Unemployment
# 0          12.4
# 1          15.2
# 2          11.3
# 3          13.7
# 4          13.7
#
# [5 rows x 28 columns]

# %%
#drop Native, Asian - Not important
census_test_data = census_test_data.drop(['Native', 'Asian'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Percent_Women  Hispanic  \
# 0      1005  Alabama   Barbour County   26201.0      46.658524       4.2
# 1      1025  Alabama    Clarke County   24625.0      52.694416       0.2
# 2      1037  Alabama     Coosa County   10955.0      50.031949       0.1
# 3      1047  Alabama    Dallas County   40755.0      53.848608       1.0
# 4      1053  Alabama  Escambia County   37621.0      48.629755       2.2
#
#    White  Black  VotingAgeCitizen  Income  ...  Drive  Carpool  Walk  \
# 0   45.7   47.8             20269   33368  ...   83.4     11.1   2.2
# 1   53.0   45.7             19087   33827  ...   83.7     11.9   0.7
# 2   65.3   33.2              8989   34792  ...   83.2      9.7   1.7
# 3   27.7   70.2             30303   30065  ...   86.6      8.9   1.7
# 4   60.2   32.2             29129   35026  ...   91.3      7.0   0.3
#
#    OtherTransp  WorkAtHome  MeanCommute  PrivateWork  PublicWork  \
# 0          1.7         1.3         23.4         74.1        19.1
# 1          2.7         0.9         23.9         83.1        11.8
# 2          0.6         4.2         29.8         78.8        15.9
# 3          1.4         1.2         22.1         78.8        15.2
# 4          0.5         0.8         22.6         75.6        19.7
#
#    SelfEmployed  Unemployment
# 0           6.5          12.4
# 1           5.1          15.2
# 2           5.4          11.3
# 3           5.6          13.7
# 4           4.6          13.7
#
# [5 rows x 26 columns]

# %%
#drop Office, Construction - Not important
census_test_data = census_test_data.drop(['Office', 'Construction'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Percent_Women  Hispanic  \
# 0      1005  Alabama   Barbour County   26201.0      46.658524       4.2
# 1      1025  Alabama    Clarke County   24625.0      52.694416       0.2
# 2      1037  Alabama     Coosa County   10955.0      50.031949       0.1
# 3      1047  Alabama    Dallas County   40755.0      53.848608       1.0
# 4      1053  Alabama  Escambia County   37621.0      48.629755       2.2
#
#    White  Black  VotingAgeCitizen  Income  ...  Drive  Carpool  Walk  \
# 0   45.7   47.8             20269   33368  ...   83.4     11.1   2.2
# 1   53.0   45.7             19087   33827  ...   83.7     11.9   0.7
# 2   65.3   33.2              8989   34792  ...   83.2      9.7   1.7
# 3   27.7   70.2             30303   30065  ...   86.6      8.9   1.7
# 4   60.2   32.2             29129   35026  ...   91.3      7.0   0.3
#
#    OtherTransp  WorkAtHome  MeanCommute  PrivateWork  PublicWork  \
# 0          1.7         1.3         23.4         74.1        19.1
# 1          2.7         0.9         23.9         83.1        11.8
# 2          0.6         4.2         29.8         78.8        15.9
# 3          1.4         1.2         22.1         78.8        15.2
# 4          0.5         0.8         22.6         75.6        19.7
#
#    SelfEmployed  Unemployment
# 0           6.5          12.4
# 1           5.1          15.2
# 2           5.4          11.3
# 3           5.6          13.7
# 4           4.6          13.7
#
# [5 rows x 24 columns]

# %%
#drop Drive, Walk, OtherTransp - Not important
census_test_data = census_test_data.drop(['Drive', 'Walk', 'OtherTransp'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Percent_Women  Hispanic  \
# 0      1005  Alabama   Barbour County   26201.0      46.658524       4.2
# 1      1025  Alabama    Clarke County   24625.0      52.694416       0.2
# 2      1037  Alabama     Coosa County   10955.0      50.031949       0.1
# 3      1047  Alabama    Dallas County   40755.0      53.848608       1.0
# 4      1053  Alabama  Escambia County   37621.0      48.629755       2.2
#
#    White  Black  VotingAgeCitizen  Income  ...  Professional  Service  \
# 0   45.7   47.8             20269   33368  ...          25.0     16.8
# 1   53.0   45.7             19087   33827  ...          21.6     14.3
# 2   65.3   33.2              8989   34792  ...          17.6     23.2
# 3   27.7   70.2             30303   30065  ...          26.7     18.2
# 4   60.2   32.2             29129   35026  ...          24.6     21.2
#
#    Production  Carpool  WorkAtHome  MeanCommute  PrivateWork  PublicWork  \
# 0        24.1     11.1         1.3         23.4         74.1        19.1
# 1        25.6     11.9         0.9         23.9         83.1        11.8
# 2        20.9      9.7         4.2         29.8         78.8        15.9
# 3        25.3      8.9         1.2         22.1         78.8        15.2
# 4        18.3      7.0         0.8         22.6         75.6        19.7
#
#    SelfEmployed  Unemployment
# 0           6.5          12.4
# 1           5.1          15.2
# 2           5.4          11.3
# 3           5.6          13.7
# 4           4.6          13.7
#
# [5 rows x 21 columns]

# %%
#drop VotingAgeCitizen- Not important
census_test_data = census_test_data.drop(['VotingAgeCitizen'], axis=1)
census_test_data.head()
# Out:
#    CountyId    State           County  TotalPop  Percent_Women  Hispanic  \
# 0      1005  Alabama   Barbour County   26201.0      46.658524       4.2
# 1      1025  Alabama    Clarke County   24625.0      52.694416       0.2
# 2      1037  Alabama     Coosa County   10955.0      50.031949       0.1
# 3      1047  Alabama    Dallas County   40755.0      53.848608       1.0
# 4      1053  Alabama  Escambia County   37621.0      48.629755       2.2
#
#    White  Black  Income  IncomePerCap  Professional  Service  Production  \
# 0   45.7   47.8   33368         17561          25.0     16.8        24.1
# 1   53.0   45.7   33827         20765          21.6     14.3        25.6
# 2   65.3   33.2   34792         20342          17.6     23.2        20.9
# 3   27.7   70.2   30065         18248          26.7     18.2        25.3
# 4   60.2   32.2   35026         18164          24.6     21.2        18.3
#
#    Carpool  WorkAtHome  MeanCommute  PrivateWork  PublicWork  SelfEmployed  \
# 0     11.1         1.3         23.4         74.1        19.1           6.5
# 1     11.9         0.9         23.9         83.1        11.8           5.1
# 2      9.7         4.2         29.8         78.8        15.9           5.4
# 3      8.9         1.2         22.1         78.8        15.2           5.6
# 4      7.0         0.8         22.6         75.6        19.7           4.6
#
#    Unemployment
# 0          12.4
# 1          15.2
# 2          11.3
# 3          13.7
# 4          13.7

# %%
census_test_data.to_csv("test_dp_output.csv")
census_test_data
# Out:
#      CountyId        State                 County  TotalPop  Percent_Women  \
# 0        1005      Alabama         Barbour County   26201.0      46.658524
# 1        1025      Alabama          Clarke County   24625.0      52.694416
# 2        1037      Alabama           Coosa County   10955.0      50.031949
# 3        1047      Alabama          Dallas County   40755.0      53.848608
# 4        1053      Alabama        Escambia County   37621.0      48.629755
# ..        ...          ...                    ...       ...            ...
# 788     72107  Puerto Rico     Orocovis Municipio   21906.0      49.826532
# 789     72113  Puerto Rico        Ponce Municipio  148863.0      51.785870
# 790     72129  Puerto Rico  San Lorenzo Municipio   38689.0      51.216108
# 791     72141  Puerto Rico       Utuado Municipio   30209.0      51.385349
# 792     72151  Puerto Rico      Yabucoa Municipio   35025.0      51.508922
#
#      Hispanic  White  Black  Income  IncomePerCap  Professional  Service  \
# 0         4.2   45.7   47.8   33368         17561          25.0     16.8
# 1         0.2   53.0   45.7   33827         20765          21.6     14.3
# 2         0.1   65.3   33.2   34792         20342          17.6     23.2
# 3         1.0   27.7   70.2   30065         18248          26.7     18.2
# 4         2.2   60.2   32.2   35026         18164          24.6     21.2
# ..        ...    ...    ...     ...           ...           ...      ...
# 788      99.7    0.3    0.0   14296          7326          26.2     17.1
# 789      99.3    0.6    0.1   16561         10775          32.0     21.2
# 790      99.9    0.0    0.0   18589         10497          32.0     20.4
# 791      99.5    0.4    0.1   15931          8140          24.7     24.4
# 792      99.9    0.1    0.0   15586          8672          27.7     26.0
#
#      Production  Carpool  WorkAtHome  MeanCommute  PrivateWork  PublicWork  \
# 0          24.1     11.1         1.3         23.4         74.1        19.1
# 1          25.6     11.9         0.9         23.9         83.1        11.8
# 2          20.9      9.7         4.2         29.8         78.8        15.9
# 3          25.3      8.9         1.2         22.1         78.8        15.2
# 4          18.3      7.0         0.8         22.6         75.6        19.7
# ..          ...      ...         ...          ...          ...         ...
# 788        12.1      6.4         3.3         33.9         57.1        31.8
# 789        11.0      6.6         2.1         23.2         72.6        18.9
# 790        12.1      7.8         1.0         37.1         74.5        20.3
# 791         9.0      8.1         2.2         33.9         58.9        29.4
# 792        16.0      9.2         0.1         30.5         62.7        30.9
#
#      SelfEmployed  Unemployment
# 0             6.5          12.4
# 1             5.1          15.2
# 2             5.4          11.3
# 3             5.6          13.7
# 4             4.6          13.7
# ..            ...           ...
# 788          10.7          32.1
# 789           8.3          15.3
# 790           5.0          11.7
# 791          11.6          30.0
# 792           6.3          25.4
#
# [793 rows x 20 columns]
